# %% [markdown]
# ## Numeros en phyton

# %%
# ENTEROS
i=12
print(i)
print(type(i))
# Out:
# 12
# <class 'int'>

# %%
#decimale
j=1.4
print(j)
print(type(j))
# Out:
# 1.4
# <class 'float'>

# %%
#convertir un decimal a entero, 
m=int(j)
print(m)
# Out:
# 1

# %%
#boleanos
t=True
f=False
print(1>0)
print(1<=0)
print(1==1)
print(2!=2)
# Out:
# True
# False
# True
# False

# %%
print(m+11==int(i))
# Out:
# True

# %% [markdown]
# ##CONDICIONALES

# %%
#IF
a=13
b=8
if a>b:
  print("Es Mayor")
# Out:
# Es Mayor

# %%
if True:
  print("Es un boleano")
# Out:
# Es un boleano

# %%
#float
r=float(m)
print(r)
# Out:
# 1.0

# %%
uno=0.99999999999999999999
print(uno)
print(uno==1) #no hay precision infinita, hay un limite
# Out:
# 1.0
# True

# %%
#precisión
q=1.0/3.0
print(q)
# Out:
# 0.3333333333333333

# %%
print("{:.20f}".format(1.0/3.0))
# Out:
# 0.33333333333333331483

# %% [markdown]
# ##NUMEROS COMPLEJOS

# %%
cm= 2 + 2j
print(cm)
print(type(cm))
# Out:
# (2+2j)
# <class 'complex'>

# %%
cm1=complex(3,4)
print(cm1)
# Out:
# (3+4j)

# %%
  print("Suma:",cm+cm1)#suma
  print("Resta:",cm-cm1)#resta
  print("Multipliacion:",cm*cm1)#multipliacion
  print("Division:",cm/cm1) #division
  print("Conjugado:",cm.conjugate())
# Out:
# Suma: (5+6j)
# Resta: (-1-2j)
# Multipliacion: (-2+14j)
# Division: (0.56-0.08j)
# Conjugado: (2-2j)

# %% [markdown]
# ##CADENAS

# %%
st="hola python"
print(st)
# Out:
# hola python

# %%
st1='hola munda'
print(st1)
# Out:
# hola munda

# %%
print("\100\110\113") #codigo asci
# Out:
# @HK

# %%
print(r"\100\110\113")
# Out:
# \100\110\113

# %%
#operaciones con cadenas
mm="soy nuevo en :"+st

print(mm)
print("es numero elejido es "+str(i))
# Out:
# soy nuevo en :hola python
# es numero elejido es 12

# %%
print(i+i)
# Out:
# 24

# %%
print("la multiplicacion es:",i*i)
# Out:
# la multiplicacion es: 144

# %%
x = 5
s = "El número es:%d" % x #otra forma de concatenar 
print(s)
# Out:
# El número es:5

# %%
print("veamos el valor de A={} y el valor de B={}".format(5,7))
print("veamos el valor de A={a} y el valor de B={b}".format(a=12,b=17))
# Out:
# veamos el valor de A=5 y el valor de B=7
# veamos el valor de A=12 y el valor de B=17

# %%
#operaciones con el nuevo f-string
aa=12
bb=5
print(f"primer valor {aa} y segundo valor {bb}")
# Out:
# primer valor 12 y segundo valor 5

# %%
cc=f"la suma de aa+bb es {aa+bb}"
print(cc)
# Out:
# la suma de aa+bb es 17

# %%
#siguiente nivel, con funciones
def funcion():
  return 20
print(f"el valor de 5x4 es {funcion()}")
# Out:
# el valor de 5x4 es 20

# %% [markdown]
# ## SETS
# No tienen un orden de almacenamiento, por lo que no se podrá acceder a travez de los indices.

# %%
#primera forma de declarar los sets
m=set([1,2,3,4,4,5,6,7,7])
m
print(m,type(m))
# Out:
# {1, 2, 3, 4, 5, 6, 7} <class 'set'>

# %%
#segunda forma de declarar a los sets
m1={1,2,3,4,4,5,6,7,7}
m1
print(m1,type(m1))
# Out:
# {1, 2, 3, 4, 5, 6, 7} <class 'set'>

# %%
#OPERACIONES

for i in m:
  print(i)

print("numero de elementos",len(m))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# numero de elementos 7

# %%
a=set([1,2,3,4])
b=set(["arbol","cedro","ishingo"])
c=(a|b)
print(c)
# Out:
# {1, 2, 3, 4, 'cedro', 'ishingo', 'arbol'}

# %% [markdown]
# ## METODOS

# %%
#agregar
m.add("pino")
print(m)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'pino'}

# %%
#remover
m.remove(3)
print(m)
# Out:
# {1, 2, 4, 5, 6, 7, 'pino'}

# %%
#elimina el primer elemento aleatorio

print(m.pop())
print(m)
# Out:
# 1
# {2, 4, 5, 6, 7, 'pino'}

# %%
#eliminar todos los elementos
m1.clear()
print(m1)
# Out:
# set()

# %% [markdown]
# ## TUPLAS

# %%
#primera forma de crear tuplas
tupla = ("rosa", "clabel", "tulipan")
print(tupla,type(tupla))
# Out:
# ('rosa', 'clabel', 'tulipan') <class 'tuple'>

# %%
# segunda forma de crear tuplas
tupla1=1,2,3,4
print(tupla1, type(tupla1))
# Out:
# (1, 2, 3, 4) <class 'tuple'>

# %%
#iterar con tuplas
for i in tupla:
  print(i)
# Out:
# rosa
# clabel
# tulipan

# %%
#no se pude hacer
#tupla[0]=4
tupla.index("tulipan")
# Out:
# 2
